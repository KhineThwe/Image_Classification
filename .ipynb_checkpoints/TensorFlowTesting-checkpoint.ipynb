# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import os 
import numpy as np

# %%
img = image.load_img("training/happy/1.jfif")
plt.imshow(img)

# %%
cv2.imread("training/happy/1.jfif").shape
# Out:
# (1658, 2529, 3)

# %%
cv2.imread("training/happy/1.jfif")
# Out:
# array([[[ 53,  51,  51],
#         [ 53,  51,  51],
#         [ 53,  51,  51],
#         ...,
#         [ 48,  47,  49],
#         [ 48,  47,  49],
#         [ 49,  48,  50]],
#
#        [[ 53,  51,  51],
#         [ 53,  51,  51],
#         [ 53,  51,  51],
#         ...,
#         [ 48,  47,  49],
#         [ 48,  47,  49],
#         [ 48,  47,  49]],
#
#        [[ 53,  51,  51],
#         [ 53,  51,  51],
#         [ 53,  51,  51],
#         ...,
#         [ 48,  47,  49],
#         [ 48,  47,  49],
#         [ 47,  46,  48]],
#
#        ...,
#
#        [[ 26, 120,  79],
#         [ 26, 120,  79],
#         [ 26, 120,  79],
#         ...,
#         [ 18, 102,  60],
#         [ 20, 102,  60],
#         [ 16, 104,  64]],
#
#        [[ 30, 122,  79],
#         [ 30, 122,  79],
#         [ 30, 122,  81],
#         ...,
#         [ 20, 103,  64],
#         [ 20, 103,  64],
#         [ 17, 103,  63]],
#
#        [[ 30, 122,  79],
#         [ 30, 122,  79],
#         [ 30, 122,  81],
# ...

# %%
train =  ImageDataGenerator(rescale = 1/255)
validation =  ImageDataGenerator(rescale = 1/255)

# %%
train_data_set = train.flow_from_directory(directory= "training/",target_size=(200,200)
                                           ,batch_size=3
                                           , shuffle=False, class_mode= 'binary')
validation_data_set = train.flow_from_directory(directory= "validation/",target_size=(200,200)
                                           ,batch_size=3
                                           , shuffle=False, class_mode= 'binary')
# Out:
# Found 3 images belonging to 2 classes.
# Found 3 images belonging to 2 classes.

# %%
train_data_set.class_indices
# Out:
# {'happy': 0, 'unhappy': 1}

# %%
train_data_set.classes
# Out:
# array([0, 1, 1])

# %%
model=tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3),activation='relu', input_shape=(200,200,3)),
                                  tf.keras.layers.MaxPool2D(2,2),
                                   #
                                 tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
                                 tf.keras.layers.MaxPool2D(2,2),
                                 ##
                                 tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
                                 tf.keras.layers.MaxPool2D(2,2),
                            
                                 tf.keras.layers.Flatten(),
                                 tf.keras.layers.Dense(512,activation='relu'),
                                 tf.keras.layers.Dense(1,activation='sigmoid')
                                 ])
# tf.keras.layers.Conv2D(16,(3,3),activation='relu',input_shape(200,200,3)),
#                             tf.keras.layers.MaxPool2D(2,2),
#                             #
#                             tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
#                             tf.keras.layers.MaxPool2D(2,2),
#                             ##
#                             tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
#                             tf.keras.layers.MaxPool2D(2,2),
                            
#                             tf.keras.layers.Flatten(),
#                             tf.keras.layers.Dense(512,activation='relu'),
#                             tf.keras.layers.Dense(1,activation='sigmoid')

# %%
model.compile(loss="binary_crossentropy",
             optimizer = RMSprop(lr=0.001),
             metrics = ['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.

# %%
model_fit = model.fit(train_data_set,
                     steps_per_epoch=3,
                     epochs=10,
                     validation_data=validation_data_set)
# Out:
# Epoch 1/10
# 1/3 [=========>....................] - ETA: 3s - loss: 12.5088 - accuracy: 0.6667WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 30 batches). You may need to use the repeat() function when building your dataset.
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 30 batches). You may need to use the repeat() function when building your dataset.
# 3/3 [==============================] - 2s 235ms/step - loss: 12.5088 - accuracy: 0.6667 - val_loss: 4.9634 - val_accuracy: 0.3333

# %%
dir_path = 'testing/'
for i in os.listdir(dir_path):
    img = image.load_img(dir_path+'//'+i,target_size=(200,200))
    plt.imshow(img)
    plt.show()
    
    X = image.img_to_array(img)
    X = np.expand_dims(X,axis=0)
    images = np.vstack([X])
    val = model.predict(images)
    if val == 0:
        print("UnHappy")
    else:
        print("happy")
# Out:
# 1/1 [==============================] - 0s 105ms/step
# UnHappy
# 1/1 [==============================] - 0s 34ms/step
# UnHappy
# 1/1 [==============================] - 0s 38ms/step
# UnHappy
# 1/1 [==============================] - 0s 48ms/step
# UnHappy
# 1/1 [==============================] - 0s 40ms/step
# UnHappy
# 1/1 [==============================] - 0s 39ms/step
# UnHappy
